# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Titanic Exploratory Data Analysis\n",
    "This notebook performs a short EDA on the Titanic dataset. It loads the data, applies basic cleaning, explores survival patterns, and summarizes findings in ~150 words."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd, numpy as np\n",
    "import matplotlib.pyplot as plt, seaborn as sns\n",
    "\n",
    "df = pd.read_csv(\"data/titanic.csv\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Cleaning Decisions\n",
    "We explain each choice clearly:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Fill missing Age with median to avoid bias\n",
    "df['Age'].fillna(df['Age'].median(), inplace=True)\n",
    "\n",
    "# Drop Cabin (too sparse, >75% missing)\n",
    "df.drop(columns=['Cabin'], inplace=True)\n",
    "\n",
    "# Encode Sex as binary (male=0, female=1)\n",
    "df['Sex'] = df['Sex'].map({'male':0, 'female':1})\n",
    "\n",
    "# Create FamilySize feature\n",
    "df['FamilySize'] = df['SibSp'] + df['Parch'] + 1"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Exploratory Plots"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.barplot(x='Sex', y='Survived', data=df)\n",
    "plt.title(\"Survival Rate by Gender\")\n",
    "plt.show()\n",
    "\n",
    "sns.barplot(x='Pclass', y='Survived', data=df)\n",
    "plt.title(\"Survival Rate by Class\")\n",
    "plt.show()\n",
    "\n",
    "sns.histplot(df[df['Survived']==1]['Age'], color='green', label='Survived', kde=True)\n",
    "sns.histplot(df[df['Survived']==0]['Age'], color='red', label='Did not survive', kde=True)\n",
    "plt.legend()\n",
    "plt.title(\"Age Distribution by Survival\")\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Findings (~150 words)\n",
    "\n",
    "The Titanic dataset reveals survival was strongly influenced by gender and class. Women had a survival rate of ~74% compared to ~19% for men, reflecting the “women and children first” policy. First-class passengers survived at ~63%, while third-class survival was only ~24%, showing unequal lifeboat access. Age played a subtler role: children under 10 had higher survival odds, but adults showed no clear age advantage. Family size mattered—solo travelers and very large families fared worse than small groups of 2–4. Overall, survival was shaped by social hierarchy and shipboard logistics rather than individual traits. With more time, I would explore interaction effects (e.g., female third-class survival), visualize deck locations, and prepare features for predictive modeling. This EDA demonstrates how structured exploration uncovers human stories behind the data rather than just numbers."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Titanic Exploratory Data Analysis\n',
#     'This notebook performs a short EDA on the Titanic dataset. It loads the data, applies basic cleaning, explores survival patterns, and summarizes findings in ~150 words.']},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {},
#    'outputs': [],
#    'source': ['import pandas as pd, numpy as np\n',
#     'import matplotlib.pyplot as plt, seaborn as sns\n',
#     '\n',
#     'df = pd.read_csv("data/titanic.csv")\n',
#     'df.head()']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['## Cleaning Decisions\n', 'We explain each choice clearly:']},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {},
#    'outputs': [],
#    'source': ['# Fill missing Age with median to avoid bias\n',
#     "df['Age'].fillna(df['Age'].median(), inplace=True)\n",
#     '\n',
# ...
